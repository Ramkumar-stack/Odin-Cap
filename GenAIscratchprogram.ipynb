# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramkumar-stack/Odin-Cap/blob/main/GenAIscratchprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install huggingface_hub
# !pip install datasets

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import pipeline

generator = pipeline('text-generation', model='gpt2')
response = generator("Once upon a time", max_length=50, num_return_sequences=1,  pad_token_id=50256,  truncation=True)
print(response[0]['generated_text'])
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Once upon a time I had met a girl who had lost her virginity in my bedroom, and she went to pick me up for her birthday. It was the first time I'd ever met someone who had been married and only had one boyfriend at least

# %%
from transformers import pipeline

s_pipeline = pipeline('sentiment-analysis',model='distilbert-base-uncased-finetuned-sst-2-english')
response = s_pipeline("I love him")
print(response[0])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# {'label': 'POSITIVE', 'score': 0.9998478889465332}

# %%
from transformers import pipeline

qa_pipeline = pipeline('question-answering', model='distilbert-base-cased-distilled-squad')

response = qa_pipeline({
    'question': "What is Generative AI?",
    'context': "Generative AI refers to artificial intelligence models that can generate new content, such as text, images, or music, based on the data they were trained on."
})
print(response)
# Out:
# {'score': 0.35779401659965515, 'start': 24, 'end': 54, 'answer': 'artificial intelligence models'}

# %%
from transformers import pipeline

# Create a question answering pipeline
qa_pipeline = pipeline('question-answering', model='deepset/roberta-base-squad2') # read this model

# Define context and question
context = "Hugging Face is a company based in New York City. It is known for developing the transformers library."
question = """Where is Hugging Face based?"""

# Answer the question
response = qa_pipeline(question=question, context=context)

# Print the question answering result
print(response)
# Out:
# {'score': 0.9825013875961304, 'start': 35, 'end': 48, 'answer': 'New York City'}

# %%
from transformers import pipeline

t_pipeline = pipeline('translation_en_to_fr',model='google-t5/t5-base')
response = t_pipeline("I love him")
print(response[0]['translation_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Je l'aime.

# %%
# Initialize the translation pipeline for French to English
t1_pipeline = pipeline('translation_fr_to_en', model='Helsinki-NLP/opus-mt-fr-en')

# Perform translation on the input text
response = t1_pipeline("Je l'aime.")

# Print the translated text
print(response[0]['translation_text'])
# Out:
# I love him.

# %%
from transformers import pipeline

t_pipeline = pipeline('summarization',model='facebook/bart-large-cnn')
response = t_pipeline(
    "I love him but she doesn't love me, so I went to focus on my work. I worked hard and got promoted.",
    max_length=10,  # Adjust this value to control the length of the summary
    min_length=10,  # Optional: Ensure the summary isn't too short
    do_sample=False  # Optional: Disable sampling for more deterministic output
)
print(response[0]['summary_text'])
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# "I love him but she doesn

# %%
from transformers import pipeline

t_pipeline = pipeline('text-classification',model='distilbert/distilbert-base-uncased-finetuned-sst-2-english')
response = t_pipeline(
    "The stock market saw significant gains today, with tech companies leading the charge..",

)
print(response[0])
# Out:
# {'label': 'POSITIVE', 'score': 0.9995518326759338}

# %%
#proper text classifecaiton - named entity recoginition.
from transformers import pipeline

ner_pipeline = pipeline('ner', model='dbmdz/bert-large-cased-finetuned-conll03-english')
# Recognize named entities
response = ner_pipeline("Hugging Face is a company based in New York City.")
print(response[0])
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'entity': 'I-ORG', 'score': 0.9943229, 'index': 1, 'word': 'Hu', 'start': 0, 'end': 2}

# %%
from transformers import pipeline

# Create a named entity recognition pipeline
ner_pipeline = pipeline('ner', model='dbmdz/bert-large-cased-finetuned-conll03-english')

# Recognize named entities in a more complex sentence
text = "Amazon, founded by Jeff sujith in Seattle, Washington, is now headquartered in Arlington, Virginia, and has acquired Whole Foods."

# Get the NER results
response = ner_pipeline(text)
print('*****',response)
# Print the named entity recognition result
for entity in response:
    print(f"Entity: {entity['word']}, Type: {entity['entity']}, Score: {entity['score']:.4f}, Start: {entity['start']}, End: {entity['end']}")
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from transformers import pipeline

generator = pipeline('text-generation', model='gpt2')
response = generator("What is Gen AI?", max_length=200, num_return_sequences=1,  truncation=True)
print(response[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# What is Gen AI?
#
# As we're used to understanding the idea, the following statements are given to clarify. All AI projects are based on intelligent AI, and every one requires a certain degree of trust that humans possess to be able to master it. And no matter how clever and smart we look at each piece of information, when our intelligence becomes available to us, it becomes more important to us. We must also take some responsibility for our own minds, the way our brains are processed around us.
#
# When you think about a piece of information, what do you look for when you want our information? How could they know what it's about? When our AI is used, we're putting at risk the safety of our lives and personal security of its human users—something many people believe is a huge mistake.
#
# ...

# %%
import nltk
from nltk.util import ngrams
from nltk.lm import Laplace
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import Vocabulary

# Download the punkt tokenizer models
nltk.download('punkt')

# Sample corpus
corpus = [
    "Once upon a time",
    "There was a little girl",
    "She lived in a small house",
    "Once upon a time there was a princess",
    "The princess lived in a castle"
]

# Tokenize the corpus
tokenized_text = [nltk.word_tokenize(sentence.lower()) for sentence in corpus]

# Prepare data for the n-gram model
train, vocab = padded_everygram_pipeline(3, tokenized_text)
model = Laplace(3)  # Trigram model with Laplace smoothing
model.fit(train, vocab)

# Generate text
def generate_text(model, seed_text, max_length=50):
    words = nltk.word_tokenize(seed_text.lower())
    print(words)
    for _ in range(max_length):
        ngram = tuple(words[-2:])  # Get last two words for trigram prediction
        #print(ngram)
        next_word = model.generate(text_seed=ngram)
        #print(next_word)
        if next_word:
            words.append(next_word)
        else:
            break
    return ' '.join(words)

# Generate text
seed_text = "Once upon a time"
generated_text = generate_text(model, seed_text)
print(generated_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['once', 'upon', 'a', 'time']
# once upon a time there was a princess </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s> </s>

# %%
import nltk
from nltk.util import ngrams
from nltk.lm import Laplace
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import Vocabulary

# Download the punkt tokenizer models
nltk.download('punkt')

# Sample corpus
corpus = [
    "Once upon a time",
    "There was a little girl",
    "She lived in a small house",
    "Once upon a time there was a princess",
    "The princess lived in a castle"
]

# Tokenize the corpus
tokenized_text = [nltk.word_tokenize(sentence.lower()) for sentence in corpus]
print(tokenized_text)
# Prepare data for the n-gram model
train, vocab = padded_everygram_pipeline(3, tokenized_text)

# Convert and print train data
print("Train (padded n-grams):")
for ngrams_list in train:
    print(list(ngrams_list))  # Convert each generator to a list

# Print the vocabulary
print("\nVocabulary:")
print("Vocabulary words:", list(vocab))

# Generate text
def generate_text(model, seed_text, max_length=5):
    words = nltk.word_tokenize(seed_text.lower())
    print(words)
    for _ in range(max_length):
        ngram = tuple(words[-2:])  # Get last two words for trigram prediction
        print(ngram)
        next_word = model.generate(text_seed=ngram)
        print(next_word)
        if next_word:
            words.append(next_word)
        else:
            break
    return ' '.join(words)

# Generate text
seed_text = "Once upon a time"
generated_text = generate_text(model, seed_text)
print(generated_text)
# Out:
# [['once', 'upon', 'a', 'time'], ['there', 'was', 'a', 'little', 'girl'], ['she', 'lived', 'in', 'a', 'small', 'house'], ['once', 'upon', 'a', 'time', 'there', 'was', 'a', 'princess'], ['the', 'princess', 'lived', 'in', 'a', 'castle']]
# Train (padded n-grams):
# [('<s>',), ('<s>', '<s>'), ('<s>', '<s>', 'once'), ('<s>',), ('<s>', 'once'), ('<s>', 'once', 'upon'), ('once',), ('once', 'upon'), ('once', 'upon', 'a'), ('upon',), ('upon', 'a'), ('upon', 'a', 'time'), ('a',), ('a', 'time'), ('a', 'time', '</s>'), ('time',), ('time', '</s>'), ('time', '</s>', '</s>'), ('</s>',), ('</s>', '</s>'), ('</s>',)]
# ...

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Encode input text
input_text = "Once upon a time"
input_ids = tokenizer.encode(input_text, return_tensors='pt')

# Generate text
output = model.generate(input_ids, max_length=50, num_return_sequences=1)

# Decode and print the generated text
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token.As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Once upon a time, the world was a place of great beauty and great danger. The world was a place of great danger, and the world was a place of great danger. The world was a place of great danger, and the world was a

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-70-1f17938aaab4> in <cell line: 2>()
#       1 import torch
# ----> 2 from diffusers import StableDiffusionPipeline
#       3 from PIL import Image
#       4
#       5 # Load the model
#
# ModuleNotFoundError: No module named 'diffusers'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
